# %%
import pandas as pd
foxconndf= pd.read_csv('jpy2017-2019.csv', index_col=0 )
foxconndf.dropna(how='any',inplace=True)

# %%
from sklearn import preprocessing
from keras.regularizers import l1,l2
from keras.callbacks import EarlyStopping
def normalize(df):
    newdf= df.copy()
    min_max_scaler = preprocessing.MinMaxScaler()
    
    newdf['spotbuyin'] = min_max_scaler.fit_transform(df.spotbuyin.values.reshape(-1,1))
    newdf['cashsellout'] = min_max_scaler.fit_transform(df.cashsellout.values.reshape(-1,1))
    newdf['spotsellout'] = min_max_scaler.fit_transform(df.spotsellout.values.reshape(-1,1))
    newdf['cashbuyin'] = min_max_scaler.fit_transform(df.cashbuyin.values.reshape(-1,1))
    
    return newdf

foxconndf_norm= normalize(foxconndf)
# Out:
# C:\Users\willy\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\willy\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\willy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np

def data_helper(df, time_frame):
    
    # 資料維度: 5維
    number_features = len(df.columns)

    # 將dataframe 轉成 numpy array
    datavalue = df.as_matrix()

    result = []
    # 若想要觀察的 time_frame 為20天, 需要多加一天做為驗證答案
    for index in range( len(datavalue) - (time_frame+1) ): # 從 datavalue 的第0個跑到倒數第 time_frame+1 個
        result.append(datavalue[index: index + (time_frame+1) ]) # 逐筆取出 time_frame+1 個K棒數值做為一筆 instance
    
    result = np.array(result)
    number_train = round(0.90 * result.shape[0]) # 取 result 的前90% instance做為訓練資料
    
    x_train = result[:int(number_train), :-1] # 訓練資料中, 只取每一個 time_frame 中除了最後一筆的所有資料做為feature
    y_train = result[:int(number_train), -1][:,-1] # 訓練資料中, 取每一個 time_frame 中最後一筆資料的最後一個數值(收盤價)做為答案
    
    # 測試資料
    x_test = result[int(number_train):, :-1]
    y_test = result[int(number_train):, -1][:,-1]
    
    # 將資料組成變好看一點
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], number_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], number_features))  

    return [x_train, y_train, x_test, y_test]

# 以20天為一區間進行股價預測
X_train, y_train, X_test, y_test = data_helper(foxconndf_norm, 5)
# Out:
# C:\Users\willy\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
from keras.layers.embeddings import Embedding
def build_model(input_length, input_dim):
    d = 0.2
    model = Sequential()
   # model.add(Embedding(output_dim=32,
    #                    input_dim=1,
     #                  input_length=10))
   # model.add(Dropout(0.2))
    model.add(LSTM(1024, input_shape=(input_length, input_dim), return_sequences=True,kernel_regularizer=l2(0.01)))

    model.add(LSTM(1024, return_sequences=False))
    #model.add(Dropout(d))
    model.add(Dense(256,kernel_initializer="uniform",activation='relu'))
    model.add(Dense(128,kernel_initializer="uniform",activation='relu'))
    model.add(Dense(64,kernel_initializer="uniform",activation='relu'))
    model.add(Dense(16,kernel_initializer="uniform",activation='relu'))
    model.add(Dense(4,kernel_initializer="uniform",activation='relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(1,kernel_initializer="uniform",activation='linear'))

    model.compile(loss='mse',optimizer='adam', metrics=['accuracy'])

    return model

# x天、x維
model = build_model( 5,4)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 1024)           4214784
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1024)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 68
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 12,912,153
# Trainable params: 12,912,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 一個batch有128個instance，總共跑50個迭代
model.fit( X_train, y_train, batch_size=128, epochs=100, validation_split=0.001, verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\willy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 665 samples, validate on 1 samples
# Epoch 1/100
# 665/665 [==============================] - 5s 7ms/step - loss: 0.1947 - accuracy: 0.0015 - val_loss: 0.4473 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.1629 - accuracy: 0.0015 - val_loss: 0.4176 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.1401 - accuracy: 0.0015 - val_loss: 0.3962 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.1247 - accuracy: 0.0015 - val_loss: 0.3805 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.1145 - accuracy: 0.0015 - val_loss: 0.3682 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.1072 - accuracy: 0.0015 - val_loss: 0.3559 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0980 - accuracy: 0.0015 - val_loss: 0.2806 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0430 - accuracy: 0.0015 - val_loss: 0.1238 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0293 - accuracy: 0.0015 - val_loss: 0.1580 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0219 - accuracy: 0.0015 - val_loss: 0.0517 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0211 - accuracy: 0.0015 - val_loss: 0.1275 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0206 - accuracy: 0.0015 - val_loss: 0.0847 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0201 - accuracy: 0.0015 - val_loss: 0.0965 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0195 - accuracy: 0.0015 - val_loss: 0.0969 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0193 - accuracy: 0.0015 - val_loss: 0.0883 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0189 - accuracy: 0.0015 - val_loss: 0.1011 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0191 - accuracy: 0.0015 - val_loss: 0.0890 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0186 - accuracy: 0.0015 - val_loss: 0.0962 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0186 - accuracy: 0.0015 - val_loss: 0.0865 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0177 - accuracy: 0.0015 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0158 - accuracy: 0.0015 - val_loss: 0.0654 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0089 - accuracy: 0.0015 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0084 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0062 - accuracy: 0.0015 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0058 - accuracy: 0.0015 - val_loss: 0.0165 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0047 - accuracy: 0.0015 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0040 - accuracy: 0.0015 - val_loss: 7.8238e-04 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0044 - accuracy: 0.0015 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0047 - accuracy: 0.0015 - val_loss: 0.0099 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0041 - accuracy: 0.0015 - val_loss: 6.5601e-04 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0042 - accuracy: 0.0015 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0053 - accuracy: 0.0015 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0050 - accuracy: 0.0015 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0044 - accuracy: 0.0015 - val_loss: 0.0092 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0057 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0066 - accuracy: 0.0015 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0061 - accuracy: 0.0015 - val_loss: 0.0141 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0056 - accuracy: 0.0015 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0040 - accuracy: 0.0015 - val_loss: 7.1929e-04 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0040 - accuracy: 0.0015 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 7.7768e-04 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 4.1856e-04 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 3.6283e-04 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 665/665 [==============================] - 3s 5ms/step - loss: 0.0043 - accuracy: 0.0015 - val_loss: 4.9327e-04 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0049 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 8.0283e-04 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0040 - accuracy: 0.0015 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0094 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0051 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 3.6464e-04 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0040 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 3.6880e-04 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 3.2338e-04 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 4.8890e-04 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 3.4522e-04 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0033 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 665/665 [==============================] - 4s 6ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 665/665 [==============================] - 4s 5ms/step - loss: 0.0031 - accuracy: 0.0015 - val_loss: 6.0035e-04 - val_accuracy: 0.0000e+00

# %%
def denormalize(df, norm_value):
    original_value = df['cashbuyin'].values.reshape(-1,1)
    norm_value = norm_value.reshape(-1,1)
    
    min_max_scaler = preprocessing.MinMaxScaler()
    min_max_scaler.fit_transform(original_value)
    denorm_value = min_max_scaler.inverse_transform(norm_value)
    
    return denorm_value

# 用訓練好的 LSTM 模型對測試資料集進行預測
pred = model.predict(X_test)

# 將預測值與正確答案還原回原來的區間值
denorm_pred = denormalize(foxconndf, pred)
denorm_ytest = denormalize(foxconndf, y_test)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

plt.plot(denorm_pred,color='red', label='Prediction')
plt.plot(denorm_ytest,color='blue', label='Answer')
plt.legend(loc='best')
plt.show()
